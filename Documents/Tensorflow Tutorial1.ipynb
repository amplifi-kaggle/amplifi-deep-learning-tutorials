# %%
import tensorflow as tf

node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)

print(node1, node2)

sess = tf.Session()
print("sess.run([nod1, node2]):", sess.run([node1, node2]))

node3 = tf.add(node1, node2)
print("node3: ", node3)
print("sess.run(node3): ", sess.run(node3))
# Out:
# Tensor("Const_2:0", shape=(), dtype=float32) Tensor("Const_3:0", shape=(), dtype=float32)
# sess.run([nod1, node2]): [3.0, 4.0]
# node3:  Tensor("Add_1:0", shape=(), dtype=float32)
# sess.run(node3):  7.0

# %%
import numpy as np
import tensorflow as tf

points = np.zeros([2000, 2])

vectors = tf.constant(points)
expanded_vectors = tf.expand_dims(vectors, 0)

print("Shape of points", vectors.get_shape())
print("Shape of expanded vec", expanded_vectors.get_shape())

'''
tf.shape
tf.size
tf.rank
tf.reshape
tf.squeeze
tf.expand_dims
tf.slice
tf.split
tf.tile
tf.concat
tf.reverse
tf.transpose
'''

a = tf.constant([1, 2, 3, 4, 5])
b = tf.constant(3)

c = tf.size(a)
sess = tf.Session()
print(sess.run(c))

'''
tf.zeros_like
tf.ones_like
tf.fill
tf.constant

tf.random_normal
tf.truncated_normal
tf.random_uniform
tf.random_shuffle
'''

'''
placeholder: 프로그램 실행 중에 데이터 변경하기 위해 '심벌릭' 변수, 즉 placeholder 사용
'''
a = tf.placeholder("float")
b = tf.placeholder("float")

y = tf.multiply(a, b)

sess = tf.Session()
print(sess.run(y, feed_dict = {a:3, b:3}))
# Out:
# Shape of points (2000, 2)
# Shape of expanded vec (1, 2000, 2)
# 5

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 

num_points = 1000

vectors_set=[]

for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1 = x1 *0.1+0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1,y1])
    
x_data = [ v[0] for v in vectors_set]
y_data = [ v[1] for v in vectors_set]

plt.plot(x_data, y_data, 'ro')

plt.show()

# %%
import tensorflow as tf

# Step 2: create placeholders for inputs

# Step 3: create weight and bias
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
print(tf.Session().run(tf.random_uniform([3], -1.0, 1.0)))
b = tf.Variable(tf.zeros([1]))
print(tf.Session().run(tf.zeros([3])))

y = W * x_data + b
# print(tf.Session().run(y))

# print(tf.random_uniform([1], -1.0, 1.0))
      
# Step 5: use the square error as the loss function
loss = tf.reduce_mean(tf.square(y - y_data))

# Step 6: using gradient descent to minimize loss
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# Step 7: call session and initialize w and b
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
# Out:
# [ 0.20065093  0.03820467  0.79767537]
# [ 0.  0.  0.]

# %%
for step in range(50):
    # Step 8: train the model
    sess.run(train)
    w_, b_, loss_ = sess.run([W, b, loss])
    # Print the results
    print('step: {:01d} | W : {:.4f} | b : {:.4f} | Loss: {:.4f}'.format(step, float(w_), float(b_), float(loss_)))
    # Plot the results
    fig = plt.figure()
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, w_ * x_data + b_)
    plt.xlabel('x')
    plt.xlim(-2, 2)
    plt.ylim(0.1, 0.6)
    plt.ylabel('y')
    plt.legend()
    plt.show()
    # Save the plot results
# Out:
# step: 0 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# C:\Users\SEC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# step: 1 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 2 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 3 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 4 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 5 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 6 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 7 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 8 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 9 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 10 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 11 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 12 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 13 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# step: 14 | W : 0.1029 | b : 0.3001 | Loss: 0.0009
# ...
